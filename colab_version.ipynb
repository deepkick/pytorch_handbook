# %% [markdown]
# <a href="https://colab.research.google.com/github/deepkick/pytorch_handbook/blob/master/colab_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)

import keras
print(keras.__version__)
# Out:
# 2.2.0-rc2
# 2.2.5
# Using TensorFlow backend.

# %%
import platform
print("python " + platform.python_version())
# Out:
# python 3.6.9

# %%
import pkg_resources
for dist in pkg_resources.working_set:
  print(dist)
# Out:
# zipp 3.1.0
# zict 2.0.0
# yellowbrick 0.9.1
# xlwt 1.3.0
# xlrd 1.1.0
# xgboost 0.90
# xarray 0.15.1
# wrapt 1.12.1
# wordcloud 1.5.0
# widgetsnbextension 3.5.1
# wheel 0.34.2
# Werkzeug 1.0.1
# webencodings 0.5.1
# wcwidth 0.1.9
# wasabi 0.6.0
# vega-datasets 0.8.0
# urllib3 1.24.3
# uritemplate 3.0.1
# umap-learn 0.3.10
# tzlocal 1.5.1
# typing 3.6.6
# typing-extensions 3.6.6
# typeguard 2.7.1
# tweepy 3.6.0
# traitlets 4.3.3
# tqdm 4.38.0
# tornado 4.5.3
# torchvision 0.5.0
# torchtext 0.3.1
# torchsummary 1.5.1
# torch 1.4.0
# toolz 0.10.0
# thinc 7.4.0
# Theano 1.0.4
# textgenrnn 1.4.1
# textblob 0.15.3
# text-unidecode 1.3
# testpath 0.4.4
# terminado 0.8.3
# termcolor 1.1.0
# tensorflow 2.2.0rc2
# tensorflow-probability 0.9.0
# tensorflow-privacy 0.2.2
# tensorflow-metadata 0.21.1
# tensorflow-hub 0.8.0
# tensorflow-gcs-config 2.1.8
# tensorflow-estimator 2.2.0rc0
# tensorflow-datasets 2.1.0
# tensorflow-addons 0.8.3
# tensorboardcolab 0.0.22
# tensorboard 2.2.0
# ...
